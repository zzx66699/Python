# %%
def calc_ROAS(raw_performance, is_last_month):
    if is_last_month == True:
        return performance['Revenue_lastmonth'] / performance['Amount_spent_lastmonth']
    return performance['Revenue'] / performance['Amount_spent']

def calc_CPA(raw_performance, is_last_month):
    if is_last_month == True:
        return performance['Amount_spent_lastmonth'] / performance['Purchases_lastmonth']
    return performance['Amount_spent'] / performance['Purchases']

def calc_CR(raw_performance, is_last_month):
    if is_last_month == True:
        return performance['Purchases_lastmonth'] / performance['Link_clicks_lastmonth']
    return performance['Purchases'] / performance['Link_clicks']

# Overall_SG_thismonth['ROAS'] = Overall_SG_thismonth['Revenue'] / Overall_SG_thismonth['Amount_spent']
Overall_SG['ROAS'] = calc_ROAS(Overall_SG, False)
# Overall_SG_lastmonth['ROAS'] = Overall_SG_lastmonth['Revenue_lastmonth'] / Overall_SG_lastmonth['Amount_spent_lastmonth']
Overall_SG['ROAS_lastmonth'] = calc_ROAS(Overall_SG, True)
# Overall_SG['CPA'] = Overall_SG_thismonth['Amount_spent'] / Overall_SG_thismonth['Purchases']
Overall_SG['CPA'] = calc_CPA(Overall_SG, False)
# Overall_SG_lastmonth['CPA'] = Overall_SG_lastmonth['Amount_spent_lastmonth'] / Overall_SG_lastmonth['Purchases_lastmonth']
Overall_SG['CPA_lastmonth'] = calc_CPA(Overall_SG, True)
# Overall_SG_thismonth['CR(%)'] = (Overall_SG_thismonth['Purchases'] / Overall_SG_thismonth['Link_clicks']) * 100
Overall_SG['CR'] = calc_CR(Overall_SG, True)
# Overall_SG_lastmonth['CR(%)'] = (Overall_SG_lastmonth['Purchases_lastmonth'] / Overall_SG_lastmonth['Link_clicks_lastmonth']) * 100
Overall_SG['CR_lastmonth'] = calc_CR(Overall_SG, False)

# %%
import pandas as pd
df = pd.read_excel('fb_raw_data.xlsx')
df
# Out:
#                                       Campaign  \
# 0           C001_MY_2308_MLP_Cov_Purchase-Prop
# 1            C145_SG_2209_MLP_Cov_Purchase-Gen
# 2           C157_UK_2302_MLP_Cov_Purchase-Prop
# 3    C165_SG_2307_MLP_Cov_Purchase-Prop-APPSPG
# 4            C145_SG_2209_MLP_Cov_Purchase-Gen
# ..                                         ...
# 453         C157_UK_2302_MLP_Cov_Purchase-Prop
# 454         C157_UK_2302_MLP_Cov_Purchase-Prop
# 455  C159_SG_2303_MLP_Cov_Purchase-Retargeting
# 456  C159_SG_2303_MLP_Cov_Purchase-Retargeting
# 457  C165_SG_2307_MLP_Cov_Purchase-Prop-APPSPG
#
#                              Ad_set  \
# 0                Interest_Fertility
# 1                  Interest_newhome
# 2    Lookalike_LAL1 Quiz Completion
# 3                Interest_Fertility
# 4    Lookalike_LAL3 Quiz Completion
# ..                              ...
# 453                  Interest_Hindi
# 454                    GEO_Churches
# 455                   APP PDP - 90D
# 456                     IG Shopping
# 457              Interest_Fertility
#
#                                                Ad Currency  Amount_spent  \
# 0                Static_testimonial_spentmuch-spg      USD        438.69
# 1                   Static_malefactor_brownbg-sct      USD        188.66
# 2             Static_testimonial-skeptics-men_spg      USD        337.30
# 3                         Static_explicit-spg(v2)      USD        210.69
# 4                   Static_malefactor_brownbg-sct      USD        163.68
# ..                                            ...      ...           ...
# 453          Static_performanceanxiety-app(learn)      USD           NaN
# 454          Static_PS_fromscepticaltopregnant-v1      USD           NaN
# 455   Static_testimonial_intimacy_withproduct-app      USD           NaN
# 456  Static_testimonial-menPOV-thankful-app-alter      USD           NaN
# 457     Static_testimonial_intimacy_lifestyle-app      USD           NaN
#
#      Amount_spent_lastmonth  Amount spent (USD) Change  \
# 0                      2.25                     436.44
# 1                    399.22                    -210.56
# 2                    162.19                     175.11
# 3                    462.70                    -252.01
# 4                    240.04                     -76.36
# ..                      ...                        ...
# 453                     NaN                        NaN
# 454                     NaN                        NaN
# 455                     NaN                        NaN
# 456                     NaN                        NaN
# 457                     NaN                        NaN
#
#      Amount spent (USD) Change (%)  Impressions  Impressions_lastmonth  ...  \
# 0                     19397.333333     149787.0                  738.0  ...
# 1                       -52.742849      40373.0                89698.0  ...
# 2                       107.965966      31686.0                15577.0  ...
# 3                       -54.465096      28854.0                61292.0  ...
# 4                       -31.811365      28039.0                38065.0  ...
# ..                             ...          ...                    ...  ...
# 453                            NaN          NaN                    2.0  ...
# 454                            NaN          NaN                    1.0  ...
# 455                            NaN          NaN                    NaN  ...
# 456                            NaN          NaN                    NaN  ...
# 457                            NaN          NaN                    NaN  ...
#
#      Purchases_lastmonth  Purchases Change  Purchases Change (%)  Revenue  \
# 0                    NaN               NaN                   NaN      NaN
# 1                    8.0              -3.0                 -37.5   162.55
# 2                    2.0               NaN                   NaN      NaN
# 3                    NaN               NaN                   NaN   237.17
# 4                    5.0              -2.0                 -40.0   139.87
# ..                   ...               ...                   ...      ...
# 453                  NaN               NaN                   NaN      NaN
# 454                  NaN               NaN                   NaN      NaN
# 455                  NaN               NaN                   NaN      NaN
# 456                  NaN               NaN                   NaN      NaN
# 457                  1.0               NaN                   NaN      NaN
#
#      Revenue_lastmonth  Purchases conversion value Change  \
# 0                  NaN                                NaN
# 1               554.75                            -392.20
# 2               133.15                                NaN
# 3                  NaN                                NaN
# 4               173.73                             -33.86
# ..                 ...                                ...
# 453                NaN                                NaN
# 454                NaN                                NaN
# 455                NaN                                NaN
# 456                NaN                                NaN
# 457              33.56                                NaN
#
#      Purchases conversion value Change (%)     Ad delivery  Reporting starts  \
# 0                                      NaN          active        2023-09-01
# 1                               -70.698513          active        2023-09-01
# 2                                      NaN  not_delivering        2023-09-01
# 3                                      NaN        inactive        2023-09-01
# 4                               -19.490013          active        2023-09-01
# ..                                     ...             ...               ...
# 453                                    NaN        inactive               NaN
# 454                                    NaN        inactive               NaN
# 455                                    NaN        inactive               NaN
# 456                                    NaN        inactive               NaN
# 457                                    NaN        inactive               NaN
#
#      Reporting ends
# 0        2023-09-07
# 1        2023-09-07
# 2        2023-09-07
# 3        2023-09-07
# 4        2023-09-07
# ..              ...
# 453             NaN
# 454             NaN
# 455             NaN
# 456             NaN
# 457             NaN
#
# [458 rows x 31 columns]
